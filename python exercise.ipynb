# %%
fruits = ['apple','banana','orange']

# %%
print(fruits[0])
# Out:
# apple

# %%
numbers = [10,20,30,40]
print(numbers[1:3])
# Out:
# [20, 30]

# %%
fruits = ['apple','banana','orange']

# %%
fruits[1]= 'grape'

# %%
print(fruits)
# Out:
# ['apple', 'grape', 'orange']

# %%
fruits.append('banana')

# %%
print(fruits)
# Out:
# ['apple', 'grape', 'orange', 'banana']

# %%
fruits.pop()
# Out:
# 'banana'

# %%
print(fruits)
# Out:
# ['apple', 'grape', 'orange']

# %%
print(len(fruits))
# Out:
# 3

# %%
numbers=[2,3,1,4]
numbers.sort()

# %%
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
my_dict = {'key1':123,'key2':[12,23,33],'key3':['item0','item1','item2']}

# %%
my_dict['key3']
# Out:
# ['item0', 'item1', 'item2']

# %%
student = {
    "name": "Ali",
    "age": 23,
    "major": "Business"
}

# %%
print(student["major"])
# Out:
# Business

# %%
student["city"]= "Seoul"

# %%
print(student)
# Out:
# {'name': 'Ali', 'age': 23, 'major': 'Business', 'city': 'Seoul'}

# %%
for key in student:
    print(key)
# Out:
# name
# age
# major
# city

# %%
for value in student.values():
    print(value)
# Out:
# Ali
# 23
# Business
# Seoul

# %%
student.keys
# Out:
# <function dict.keys>

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'major', 'city'])

# %%
student.values()
# Out:
# dict_values(['Ali', 23, 'Business', 'Seoul'])

# %%
print("This is a test")
# Out:
# This is a test

# %%
example = [1,2,3,4,5,6,7]

# %%
from random import shuffle
result = shuffle(example)

# %%
result

# %%
def shuffle_list(mylist):
    shuffle(mylist)
    return mylist

# %%
result = shuffle_list(example)
result
# Out:
# [2, 3, 5, 4, 7, 1, 6]

# %%
def check_guess(mylist,guess):
    if mylist[guess] == '0':
        print("Correct!")
    else:
        print("Wrong guess!")
        print(mylist)

# %%
mylist = [' ','0',' ']

mixed_list = shuffle_mylist(mylist)

guess = player_guess()

check_guess(mixedup_list,guess)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 mylist = [' ','0',' ']
# ----> 3 mixed_list = shuffle_mylist(mylist)
#       5 guess = player_guess()
#       7 check_guess(mixedup_list,guess)
#
# NameError: name 'shuffle_mylist' is not defined

# %%
def is_even(num):
    return num %2 == 0

def count_even(numbers):
    count = 0

    for num in numbers:
        if is_even(num):
            count+= 1

    return count

# %%
count_even([1,2,3,4,5,6,8])
# Out:
# 4

# %%
def get_punched (health, armor = 0):
    damage = 50 - armor
    new_health = health - damage
    return new_health

def get_slashed(health, armor = 0):
    damage = 100 - armor
    new_health = health - damage
    return new_health

def test(health, armor):
    print(f"Running tests for health {health} and armor {armor}")
    print("========================================")
    print(f"Health: {health}, Armor: {armor}")
    print(f"Health after punch: {get_punched(health, armor)}")
    print("----------------------------------------")
    print(f"Health: {health}, Armor: {armor}")
    print(f"Health after slash: {get_slashed(health, armor)}")
    print("----------------------------------------")
    print(f"Health: {health}, Armor: no armor!")
    print(f"Health after slash: {get_slashed(health)}")
    print("----------------------------------------")
    print(f"Health: {health}, Armor: no armor!")
    print(f"Health after punch: {get_punched(health)}")
    print("----------------------------------------\n")

# %%
get_punched(500,5)
# Out:
# 455

# %%
test(1000,0)
# Out:
# Running tests for health 1000 and armor 0
# ========================================
# Health: 1000, Armor: 0
# Health after punch: 950
# ----------------------------------------
# Health: 1000, Armor: 0
# Health after slash: 900
# ----------------------------------------
# Health: 1000, Armor: no armor!
# Health after slash: 900
# ----------------------------------------
# Health: 1000, Armor: no armor!
# Health after punch: 950
# ----------------------------------------
